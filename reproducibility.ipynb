# %%
import pandas as pd
df = pd.read_csv('Peak areas.csv')
df['index']=df['Formula'].str.replace(' ','').astype(str)+'_'+df['Name'].astype(str)+'_'+df['Annot. DeltaMass [ppm]'].astype(str)
df.head()
# Out:
#                   Name          Formula  Annot. DeltaMass [ppm]   Calc. MW  \
# 0  Isovalerylcarnitine     C12 H23 N O4                    0.26  245.16277
# 1        Phenylalanine      C9 H11 N O2                    0.50  165.07906
# 2           Creatinine       C4 H7 N3 O                   -1.64  113.05873
# 3        D-(-)-Alanine       C3 H7 N O2                   -1.99   89.04750
# 4               Biotin  C10 H16 N2 O3 S                    0.17  244.08820
#
#          m/z  RT [min]  Sample_2.raw (F4)  Sample_6.raw (F8)  \
# 0  246.17005     3.490       5.118391e+08       5.419645e+08
# 1  166.08634     4.013       2.792202e+08       2.812728e+08
# 2  114.06600     2.705       1.105390e+08       1.320892e+08
# 3   90.05478     5.289       8.737665e+07       7.876144e+07
# 4  245.09548     1.211       5.073397e+07       4.627686e+07
#
#    Sample_7.raw (F9)  Sample_12.raw (F15)  ...  Sample_14a.raw (F46)  \
# 0       6.695055e+08         9.070443e+08  ...           22911066.86
# 1       2.594075e+08         2.717674e+08  ...           93402332.91
# 2       1.030299e+08         9.634633e+07  ...           84219269.69
# 3       8.595425e+07         9.394967e+07  ...           19459905.86
# 4       4.293289e+07         4.469386e+07  ...           25949146.35
#
#    Sample_16a.raw (F48)  Sample_18a.raw (F51)  Sample_19a.raw (F52)  \
# 0          3.697091e+07           25059736.41          2.943277e+07
# 1          1.111985e+08           96582329.58          1.326147e+08
# 2          8.371297e+07           84099350.36          1.159518e+08
# 3          2.017196e+07           28050087.24          2.933373e+07
# 4          1.860639e+07           23436272.94          3.892672e+07
#
#    Sample_20a.raw (F53)  Sample_8.raw (F10)  Sample_13.raw (F16)  \
# 0           34533998.82        3.918035e+07         6.348154e+07
# 1           97283486.83        1.277075e+08         1.746037e+08
# 2           80384708.00        1.311176e+08         5.206864e+07
# 3           30071981.13        4.406625e+07         1.173264e+08
# 4           25566403.48        2.151312e+07         3.447886e+07
#
#    Sample_8a.raw (F39)  Sample_13a.raw (F45)  \
# 0         1.645082e+07           47510046.38
# 1         9.903284e+07           84819761.19
# 2         1.117317e+08           52285191.68
# 3         2.796933e+07           56727003.20
# 4         2.807806e+07           23332732.01
#
#                                 index
# 0  C12H23NO4_Isovalerylcarnitine_0.26
# 1          C9H11NO2_Phenylalanine_0.5
# 2            C4H7N3O_Creatinine_-1.64
# 3         C3H7NO2_D-(-)-Alanine_-1.99
# 4             C10H16N2O3S_Biotin_0.17
#
# [5 rows x 58 columns]

# %%
df[df['Name']=='gamma-Glutamylalanine']
df = df.drop(45)
df=df.reset_index()
df.shape
# Out:
# (46, 59)

# %%
import numpy as np
#np.log(df[df['Name']=='gamma-Glutamylalanine'].iloc[:,6:-1]).T.plot(x=27,y=45,kind='scatter')

# %%
selection = df.set_index('index').iloc[:,7:]
print(selection.shape)
selection.head()
# Out:
# (46, 51)
#                                     Sample_2.raw (F4)  Sample_6.raw (F8)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26       5.118391e+08       5.419645e+08
# C9H11NO2_Phenylalanine_0.5               2.792202e+08       2.812728e+08
# C4H7N3O_Creatinine_-1.64                 1.105390e+08       1.320892e+08
# C3H7NO2_D-(-)-Alanine_-1.99              8.737665e+07       7.876144e+07
# C10H16N2O3S_Biotin_0.17                  5.073397e+07       4.627686e+07
#
#                                     Sample_7.raw (F9)  Sample_12.raw (F15)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26       6.695055e+08         9.070443e+08
# C9H11NO2_Phenylalanine_0.5               2.594075e+08         2.717674e+08
# C4H7N3O_Creatinine_-1.64                 1.030299e+08         9.634633e+07
# C3H7NO2_D-(-)-Alanine_-1.99              8.595425e+07         9.394967e+07
# C10H16N2O3S_Biotin_0.17                  4.293289e+07         4.469386e+07
#
#                                     Sample_15.raw (F18)  Sample_17.raw (F21)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26         4.625111e+08         5.684665e+08
# C9H11NO2_Phenylalanine_0.5                 2.755865e+08         2.073515e+08
# C4H7N3O_Creatinine_-1.64                   1.250872e+08         6.697208e+07
# C3H7NO2_D-(-)-Alanine_-1.99                7.321021e+07         7.130992e+07
# C10H16N2O3S_Biotin_0.17                    3.031389e+07         4.048891e+07
#
#                                     Sample_2a.raw (F33)  Sample_6a.raw (F37)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26         1.766677e+08         1.770912e+08
# C9H11NO2_Phenylalanine_0.5                 5.915831e+07         7.884840e+07
# C4H7N3O_Creatinine_-1.64                   2.734699e+07         4.250530e+07
# C3H7NO2_D-(-)-Alanine_-1.99                2.500834e+07         2.945397e+07
# C10H16N2O3S_Biotin_0.17                    1.203074e+07         1.612548e+07
#
#                                     Sample_7a.raw (F38)  Sample_12a.raw (F44)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26         2.359176e+08          2.265437e+08
# C9H11NO2_Phenylalanine_0.5                 1.700720e+08          8.907352e+07
# C4H7N3O_Creatinine_-1.64                   1.325695e+08          4.469304e+07
# C3H7NO2_D-(-)-Alanine_-1.99                4.175380e+07          3.706628e+07
# C10H16N2O3S_Biotin_0.17                    3.803387e+07          2.192118e+07
#
#                                     ...  Sample_11a.raw (F43)  \
# index                               ...
# C12H23NO4_Isovalerylcarnitine_0.26  ...          3.880257e+07
# C9H11NO2_Phenylalanine_0.5          ...          1.072008e+08
# C4H7N3O_Creatinine_-1.64            ...          8.510393e+07
# C3H7NO2_D-(-)-Alanine_-1.99         ...          1.870180e+07
# C10H16N2O3S_Biotin_0.17             ...          2.698666e+07
#
#                                     Sample_14a.raw (F46)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26           22911066.86
# C9H11NO2_Phenylalanine_0.5                   93402332.91
# C4H7N3O_Creatinine_-1.64                     84219269.69
# C3H7NO2_D-(-)-Alanine_-1.99                  19459905.86
# C10H16N2O3S_Biotin_0.17                      25949146.35
#
#                                     Sample_16a.raw (F48)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26          3.697091e+07
# C9H11NO2_Phenylalanine_0.5                  1.111985e+08
# C4H7N3O_Creatinine_-1.64                    8.371297e+07
# C3H7NO2_D-(-)-Alanine_-1.99                 2.017196e+07
# C10H16N2O3S_Biotin_0.17                     1.860639e+07
#
#                                     Sample_18a.raw (F51)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26           25059736.41
# C9H11NO2_Phenylalanine_0.5                   96582329.58
# C4H7N3O_Creatinine_-1.64                     84099350.36
# C3H7NO2_D-(-)-Alanine_-1.99                  28050087.24
# C10H16N2O3S_Biotin_0.17                      23436272.94
#
#                                     Sample_19a.raw (F52)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26          2.943277e+07
# C9H11NO2_Phenylalanine_0.5                  1.326147e+08
# C4H7N3O_Creatinine_-1.64                    1.159518e+08
# C3H7NO2_D-(-)-Alanine_-1.99                 2.933373e+07
# C10H16N2O3S_Biotin_0.17                     3.892672e+07
#
#                                     Sample_20a.raw (F53)  Sample_8.raw (F10)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26           34533998.82        3.918035e+07
# C9H11NO2_Phenylalanine_0.5                   97283486.83        1.277075e+08
# C4H7N3O_Creatinine_-1.64                     80384708.00        1.311176e+08
# C3H7NO2_D-(-)-Alanine_-1.99                  30071981.13        4.406625e+07
# C10H16N2O3S_Biotin_0.17                      25566403.48        2.151312e+07
#
#                                     Sample_13.raw (F16)  Sample_8a.raw (F39)  \
# index
# C12H23NO4_Isovalerylcarnitine_0.26         6.348154e+07         1.645082e+07
# C9H11NO2_Phenylalanine_0.5                 1.746037e+08         9.903284e+07
# C4H7N3O_Creatinine_-1.64                   5.206864e+07         1.117317e+08
# C3H7NO2_D-(-)-Alanine_-1.99                1.173264e+08         2.796933e+07
# C10H16N2O3S_Biotin_0.17                    3.447886e+07         2.807806e+07
#
#                                     Sample_13a.raw (F45)
# index
# C12H23NO4_Isovalerylcarnitine_0.26           47510046.38
# C9H11NO2_Phenylalanine_0.5                   84819761.19
# C4H7N3O_Creatinine_-1.64                     52285191.68
# C3H7NO2_D-(-)-Alanine_-1.99                  56727003.20
# C10H16N2O3S_Biotin_0.17                      23332732.01
#
# [5 rows x 51 columns]

# %%
selection=np.log10(selection)

# %%
selection.plot(kind='box')
# Out:
# <Axes: >

# %%
#selection.mean().sort_values()

# %%
#del selection['Solvent_Blank.raw (F27)']

# %%
selection.columns
# Out:
# Index(['Sample_2.raw (F4)', 'Sample_6.raw (F8)', 'Sample_7.raw (F9)',
#        'Sample_12.raw (F15)', 'Sample_15.raw (F18)', 'Sample_17.raw (F21)',
#        'Sample_2a.raw (F33)', 'Sample_6a.raw (F37)', 'Sample_7a.raw (F38)',
#        'Sample_12a.raw (F44)', 'Sample_15a.raw (F47)', 'Sample_17a.raw (F50)',
#        'QC9.raw (F1)', 'QC10.raw (F2)', 'QC11.raw (F11)', 'QC12.raw (F20)',
#        'Solvent_Blank.raw (F27)', 'QC13.raw (F28)', 'QC14.raw (F29)',
#        'QCB4.raw (F30)', 'QCB5.raw (F31)', 'QCB6.raw (F40)', 'QCB7.raw (F49)',
#        'QCB8.raw (F56)', 'QCB9.raw (F57)', 'Sample_1.raw (F3)',
#        'Sample_3.raw (F5)', 'Sample_4.raw (F6)', 'Sample_5.raw (F7)',
#        'Sample_10.raw (F13)', 'Sample_11.raw (F14)', 'Sample_14.raw (F17)',
#        'Sample_16.raw (F19)', 'Sample_18.raw (F22)', 'Sample_19.raw (F23)',
#        'Sample_20.raw (F24)', 'Sample_1a.raw (F32)', 'Sample_3a.raw (F34)',
#        'Sample_4a.raw (F35)', 'Sample_5a.raw (F36)', 'Sample_10a.raw (F42)',
#        'Sample_11a.raw (F43)', 'Sample_14a.raw (F46)', 'Sample_16a.raw (F48)',
#        'Sample_18a.raw (F51)', 'Sample_19a.raw (F52)', 'Sample_20a.raw (F53)',
#        'Sample_8.raw (F10)', 'Sample_13.raw (F16)', 'Sample_8a.raw (F39)',
#        'Sample_13a.raw (F45)'],
#       dtype='object')

# %%
import seaborn as sns

# %%
def quant_norm(df):
    ranks = (df.rank(method="first")
              .stack())
    rank_mean = (df.stack()
                   .groupby(ranks)
                   .mean())
    # Add interpolated values in between ranks
    finer_ranks = ((rank_mean.index+0.5).to_list() +
                    rank_mean.index.to_list())
    rank_mean = rank_mean.reindex(finer_ranks).sort_index().interpolate()
    return (df.rank(method='average')
              .stack()
              .map(rank_mean)
              .unstack())
selection_norm = quant_norm(selection.reset_index(drop=True))
selection_norm.index = selection.index.values
selection_norm.head()
# Out:
#                                     Sample_2.raw (F4)  Sample_6.raw (F8)  \
# C12H23NO4_Isovalerylcarnitine_0.26           8.250099           8.250099
# C9H11NO2_Phenylalanine_0.5                   8.062080           8.062080
# C4H7N3O_Creatinine_-1.64                     7.799990           7.799990
# C3H7NO2_D-(-)-Alanine_-1.99                  7.596857           7.596857
# C10H16N2O3S_Biotin_0.17                      7.425099           7.425099
#
#                                     Sample_7.raw (F9)  Sample_12.raw (F15)  \
# C12H23NO4_Isovalerylcarnitine_0.26           8.250099             8.250099
# C9H11NO2_Phenylalanine_0.5                   8.062080             8.062080
# C4H7N3O_Creatinine_-1.64                     7.799990             7.799990
# C3H7NO2_D-(-)-Alanine_-1.99                  7.596857             7.596857
# C10H16N2O3S_Biotin_0.17                      7.425099             7.425099
#
#                                     Sample_15.raw (F18)  Sample_17.raw (F21)  \
# C12H23NO4_Isovalerylcarnitine_0.26             8.250099             8.250099
# C9H11NO2_Phenylalanine_0.5                     8.062080             8.062080
# C4H7N3O_Creatinine_-1.64                       7.799990             7.596857
# C3H7NO2_D-(-)-Alanine_-1.99                    7.596857             7.799990
# C10H16N2O3S_Biotin_0.17                        7.129641             7.425099
#
#                                     Sample_2a.raw (F33)  Sample_6a.raw (F37)  \
# C12H23NO4_Isovalerylcarnitine_0.26             8.250099             8.250099
# C9H11NO2_Phenylalanine_0.5                     8.062080             8.062080
# C4H7N3O_Creatinine_-1.64                       7.799990             7.799990
# C3H7NO2_D-(-)-Alanine_-1.99                    7.596857             7.596857
# C10H16N2O3S_Biotin_0.17                        7.425099             7.425099
#
#                                     Sample_7a.raw (F38)  Sample_12a.raw (F44)  \
# C12H23NO4_Isovalerylcarnitine_0.26             8.250099              8.250099
# C9H11NO2_Phenylalanine_0.5                     8.062080              8.062080
# C4H7N3O_Creatinine_-1.64                       7.799990              7.799990
# C3H7NO2_D-(-)-Alanine_-1.99                    7.596857              7.596857
# C10H16N2O3S_Biotin_0.17                        7.425099              7.425099
#
#                                     ...  Sample_11a.raw (F43)  \
# C12H23NO4_Isovalerylcarnitine_0.26  ...              7.799990
# C9H11NO2_Phenylalanine_0.5          ...              8.250099
# C4H7N3O_Creatinine_-1.64            ...              8.062080
# C3H7NO2_D-(-)-Alanine_-1.99         ...              7.425099
# C10H16N2O3S_Biotin_0.17             ...              7.596857
#
#                                     Sample_14a.raw (F46)  \
# C12H23NO4_Isovalerylcarnitine_0.26              7.596857
# C9H11NO2_Phenylalanine_0.5                      8.250099
# C4H7N3O_Creatinine_-1.64                        8.062080
# C3H7NO2_D-(-)-Alanine_-1.99                     7.425099
# C10H16N2O3S_Biotin_0.17                         7.799990
#
#                                     Sample_16a.raw (F48)  \
# C12H23NO4_Isovalerylcarnitine_0.26              7.799990
# C9H11NO2_Phenylalanine_0.5                      8.250099
# C4H7N3O_Creatinine_-1.64                        8.062080
# C3H7NO2_D-(-)-Alanine_-1.99                     7.596857
# C10H16N2O3S_Biotin_0.17                         7.425099
#
#                                     Sample_18a.raw (F51)  \
# C12H23NO4_Isovalerylcarnitine_0.26              7.596857
# C9H11NO2_Phenylalanine_0.5                      8.250099
# C4H7N3O_Creatinine_-1.64                        8.062080
# C3H7NO2_D-(-)-Alanine_-1.99                     7.799990
# C10H16N2O3S_Biotin_0.17                         7.425099
#
#                                     Sample_19a.raw (F52)  \
# C12H23NO4_Isovalerylcarnitine_0.26              7.596857
# C9H11NO2_Phenylalanine_0.5                      8.250099
# C4H7N3O_Creatinine_-1.64                        8.062080
# C3H7NO2_D-(-)-Alanine_-1.99                     7.425099
# C10H16N2O3S_Biotin_0.17                         7.799990
#
#                                     Sample_20a.raw (F53)  Sample_8.raw (F10)  \
# C12H23NO4_Isovalerylcarnitine_0.26              7.799990            7.596857
# C9H11NO2_Phenylalanine_0.5                      8.250099            8.062080
# C4H7N3O_Creatinine_-1.64                        8.062080            8.250099
# C3H7NO2_D-(-)-Alanine_-1.99                     7.596857            7.799990
# C10H16N2O3S_Biotin_0.17                         7.425099            7.425099
#
#                                     Sample_13.raw (F16)  Sample_8a.raw (F39)  \
# C12H23NO4_Isovalerylcarnitine_0.26             7.799990             7.425099
# C9H11NO2_Phenylalanine_0.5                     8.250099             8.062080
# C4H7N3O_Creatinine_-1.64                       7.596857             8.250099
# C3H7NO2_D-(-)-Alanine_-1.99                    8.062080             7.596857
# C10H16N2O3S_Biotin_0.17                        7.425099             7.799990
#
#                                     Sample_13a.raw (F45)
# C12H23NO4_Isovalerylcarnitine_0.26              7.596857
# C9H11NO2_Phenylalanine_0.5                      8.250099
# C4H7N3O_Creatinine_-1.64                        7.799990
# C3H7NO2_D-(-)-Alanine_-1.99                     8.062080
# C10H16N2O3S_Biotin_0.17                         7.425099
#
# [5 rows x 51 columns]

# %%
selection_norm.plot(kind='box')
# Out:
# <Axes: >

# %%
selection_norm.to_csv('Peak_areas_quantile_norm.csv')

# %%
sample_info = pd.read_csv('sample_info.txt',sep='\t')
sample_info.head()
# Out:
#                   NAME rename Color     CLASS
# 0    Sample_1.raw (F3)    18a  blue  Non-cytb
# 1  Sample_1a.raw (F32)    18b  blue  Non-cytb
# 2    Sample_2.raw (F4)     2a   red      Cytb
# 3  Sample_2a.raw (F33)     2b   red      Cytb
# 4    Sample_3.raw (F5)    12a  blue  Non-cytb

# %%
sample_groups = sample_info.set_index('rename')['Color'].to_dict()
color_dictionary = sample_info.set_index('Color')['CLASS'].to_dict()
rename_dict = sample_info.set_index('NAME')['rename'].to_dict()
sample_groups,color_dictionary
# Out:
# ({'18a': 'blue',
#   '18b': 'blue',
#   '2a': 'red',
#   '2b': 'red',
#   '12a': 'blue',
#   '12b': 'blue',
#   '14a': 'blue',
#   '14b': 'blue',
#   '9a': 'blue',
#   '9b': 'blue',
#   '3a': 'red',
#   '3b': 'red',
#   '6a': 'red',
#   '6b': 'red',
#   '8a': 'brown',
#   '8b': 'brown',
#   '13a': 'blue',
#   '13b': 'blue',
#   '16a': 'blue',
#   '16b': 'blue',
#   '5a': 'red',
#   '5b': 'red',
#   '7a': 'brown',
#   '7b': 'brown',
#   '19a': 'blue',
#   '19b': 'blue',
#   '4a': 'red',
#   '4b': 'red',
#   '15a': 'blue',
#   '15b': 'blue',
#   '1a': 'red',
#   '1b': 'red',
#   '17a': 'blue',
#   '17b': 'blue',
#   '10a': 'blue',
#   '10b': 'blue',
#   '11a': 'blue',
#   '11b': 'blue',
#   'QC': 'black',
#   'SB': 'white'},
#  {'blue': 'Non-cytb',
#   'red': 'Cytb',
#   'brown': 'Other OxPhos',
#   'black': 'QC',
#   'white': 'SB'})

# %%
from ProjectUtility import dim_red_utility
import matplotlib.pyplot as plt
from ProjectUtility.core import convert_palette_to_hex, create_group_color_mapping

# %%
selection_norm.index.values
# Out:
# array(['C12H23NO4_Isovalerylcarnitine_0.26', 'C9H11NO2_Phenylalanine_0.5',
#        'C4H7N3O_Creatinine_-1.64', 'C3H7NO2_D-(-)-Alanine_-1.99',
#        'C10H16N2O3S_Biotin_0.17',
#        'C8H6_[Similar to: Phenylethanolamine; ?Mass: -35.0372 Da]_-1.25',
#        'C8H9N_nan_-1.01', 'C11H12N2O2_DL-Tryptophan_-0.92',
#        'C11H9NO2_trans-3-Indoleacrylic acid_-0.88', 'C5H9N2OPS_nan_0.16',
#        'C18H37NO2_Threo-sphingosine, (-)-_0.43',
#        'C4H8N2O3_L-(-)-Asparagine_-0.09', 'C4H8NOPS_nan_0.94',
#        'C12H16N4OS_Thiamine_-0.17', 'C4H9NO3_Homoserine_-1.31',
#        'C6H15N4O5P_Phosphoarginine_0.39', 'C17H27N3O17P2_UDP-GlcNAc_2.29',
#        'C7H12N3O7PS_nan_-1.68', 'C4H7NO4_Aspartate_-0.06',
#        'C9H12N2O2_(4-Ethoxyphenyl)urea_-0.64', 'C14H27NO4_nan_0.69',
#        'C5H7N8OPS_nan_1.27',
#        'C13H9ClN2O3_2-Chloro-5-nitrobenzanilide_2.9', 'C5H7O2PS_nan_0.4',
#        'C2H5Hg_Ethyl mercury ion_-1.41', 'C10H11ClNO13P_nan_2.74',
#        'C6H16N5O9P3_nan_-1.03', 'C8H14N2O5_gamma-Glutamylalanine_-0.51',
#        'C10H14N5O7P_Adenosine monophosphate_0.43', 'C6H2N2O12_nan_1.07',
#        'C9H22NO15P3_nan_-2.27', 'C7H10NO4P_nan_-0.12',
#        'C10H13N4O8P_Inosine-monophosphate_0.79', 'C8H12ClO16P_nan_2.05',
#        'C8HCl2N4O7P_nan_-0.87',
#        'C9H14O4_cis-2-Carboxycyclohexyl-acetic acid_-1.37',
#        'C15H15ClN2O4S_Xipamide_0.94', 'C16H5ClN2P2S_nan_1.2',
#        'C25H14NO13PS_nan_0.03', 'C39H14N3O3PS2_nan_-0.5',
#        'C3H6N3P3S_nan_-2.13', 'C11H10ClN5O13P2_nan_0.81',
#        'C14H17N3O_Frovatriptan_-0.07', 'C14H26N4O11P2_Citicoline_1.41',
#        'C21H22N3O15PS3_nan_-0.49', 'C3H4Cl2N2O13P2S_nan_-0.35'],
#       dtype=object)

# %%
#dim_red_utility.create_dim_reduction_dashboard??

# %%
fig, axes, results_dict = dim_red_utility.create_dim_reduction_dashboard(
    in_df=selection_norm.drop(['Solvent_Blank.raw (F27)'],axis=1).rename(rename_dict,axis=1),
    sample_palette=sample_groups,
    feature_palette={},
    top=500,
    color_dictionary=color_dictionary,
    title="Dim Red Analysis",
    figsize=(12, 10)  
)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# Explained variance ratio: [0.56841678 0.12051229 0.08164263 0.07262084 0.03183054]
# /opt/venv/lib/python3.11/site-packages/sklearn/manifold/_mds.py:677: FutureWarning: The default value of `n_init` will change from 4 to 1 in 1.9.
#   warnings.warn(

# %%
#selection_norm.loc[['C10H11ClNO13P_nan_2.74','C11H10ClN5O13P2_nan_0.81']
color_dictionary
# Out:
# {'blue': 'Non-cytb',
#  'red': 'Cytb',
#  'brown': 'Other OxPhos',
#  'black': 'QC',
#  'white': 'SB'}

# %%
#plotter.plot_samples??

# %%
# Create a plotter instance
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plotter = dim_red_utility.DimensionalityReductionPlotter(
    in_df=selection_norm.drop(['Solvent_Blank.raw (F27)'],axis=1).rename(rename_dict,axis=1),
    top=5000,  # Use top 50 features
    color_dictionary=color_dictionary
)

# Fit PCA and plot samples
plotter.fit(method='pca', n_components=2)
fig, ax, tmp_df = plotter.plot_samples(
    palette=sample_groups,
    point_size=80,
    do_adjust_text=True,
    title="")
plt.tight_layout()
plt.savefig('PCA.svg')
#ax.savefig('PCA.svg')
# Out:
# Explained variance ratio: [0.56841678 0.12051229]

# %%
#plotter.plot_loadings??

# %%
fig, ax, tmp_df  = plotter.plot_loadings(
    palette={},
    arrow=True,
    arrow_scale=3,
    title="",
    biggest=3
    )
ax.legend('')
plt.tight_layout()
plt.savefig('Loading.svg')
#ax.savefig('Loading.svg')
